# %%
# !nvidia-smi  # confirm Tesla T4 + CUDA
# Out:
# Wed Sep 16 05:56:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/iesxz-c/Final.git
# %cd Final
# Out:
# Cloning into 'Final'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 196 (delta 86), reused 162 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (196/196), 183.36 KiB | 5.91 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# /content/Final

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p data
# !cp /content/drive/MyDrive/phase2c_remaining_702.json data/phase2c_remaining_702.json

# %%
# !python -c "import json; x=json.load(open('data/phase2c_remaining_702.json')); print(type(x)); print(x.keys() if isinstance(x,dict) else 'not a dict')"
# Out:
# <class 'dict'>
# dict_keys(['videos'])

# %%
# !python -c "import json; x=json.load(open('data/phase2c_remaining_702.json')); print(x)"
# Out:
# {'videos': [{'video_id': 'anomaly/Abuse/Abuse001_x264.mp4', 'source_type': 'anomaly', 'ground_truth_category': 'Abuse', 'dataset_root': '/content/drive/MyDrive/Anomaly-Videos-Part-1/Anomaly-Videos-Part-1', 'path': 'Abuse/Abuse001_x264.mp4', 'duration_seconds': 90.967, 'fps': 30.0, 'width': 320, 'height': 240, 'frame_count': 2729, 'file_size_bytes': 21494969, 'format': 'mp4', 'schema_version': 'phase2a/v1'}, {'video_id': 'anomaly/Abuse/Abuse002_x264.mp4', 'source_type': 'anomaly', 'ground_truth_category': 'Abuse', 'dataset_root': '/content/drive/MyDrive/Anomaly-Videos-Part-1/Anomaly-Videos-Part-1', 'path': 'Abuse/Abuse002_x264.mp4', 'duration_seconds': 28.833, 'fps': 30.0, 'width': 320, 'height': 240, 'frame_count': 865, 'file_size_bytes': 7253682, 'format': 'mp4', 'schema_version': 'phase2a/v1'}, {'video_id': 'anomaly/Abuse/Abuse003_x264.mp4', 'source_type': 'anomaly', 'ground_truth_category': 'Abuse', 'dataset_root': '/content/drive/MyDrive/Anomaly-Videos-Part-1/Anomaly-Videos-Part-
# ...

# %%
# !python -c "import json; x=json.load(open('data/phase2c_remaining_702.json')); v=x['videos']; print('Videos:',len(v)); print('Anomaly:',sum(i['source_type']=='anomaly' for i in v)); print('Unique IDs:',len({i['video_id'] for i in v})); print('Schema:',x.keys())"
# Out:
# Videos: 702
# Anomaly: 702
# Unique IDs: 702
# Schema: dict_keys(['videos'])

# %%
# !find /content/drive/MyDrive/Crime_CCTV_Project/Phase2 -maxdepth 4 -type f | grep -E "phase2c_ucf_batches|batch_|state.json"

# %%
# !mkdir -p /content/drive/MyDrive/Crime_CCTV_Project/Phase2/phase2c_ucf_batches

# %%
# !python scripts/run_resumable_ucf.py \
  --input-manifest data/phase2c_remaining_702.json \
  --output-dir /content/drive/MyDrive/Crime_CCTV_Project/Phase2/phase2c_ucf_batches \
  --device cuda
# Out:
# TOTAL: 702
# COMPLETED BEFORE START: 0
# REMAINING: 702
# CURRENT BATCH: batch_001 (50 videos)
# ...
# Event model: OPear/videomae-large-finetuned-UCF-Crime (bc5f1c1058158a05f8710de2b7c7c372fe69062b) on cuda (16 frames @ 8.0fps, top-5)
# [1/50] anomaly/Abuse/Abuse001_x264.mp4
#   43 windows (video 30.00fps)
# [2/50] anomaly/Abuse/Abuse002_x264.mp4
#   14 windows (video 30.00fps)
# [3/50] anomaly/Abuse/Abuse003_x264.mp4
#   58 windows (video 30.00fps)
# [4/50] anomaly/Abuse/Abuse004_x264.mp4
#   263 windows (video 30.00fps)
# [5/50] anomaly/Abuse/Abuse005_x264.mp4
#   15 windows (video 30.00fps)
# [6/50] anomaly/Abuse/Abuse006_x264.mp4
#   69 windows (video 30.00fps)
# [7/50] anomaly/Abuse/Abuse007_x264.mp4
#   18 windows (video 30.00fps)
# [8/50] anomaly/Abuse/Abuse008_x264.mp4
#   132 windows (video 30.00fps)
# [9/50] anomaly/Abuse/Abuse009_x264.mp4
#   16 windows (video 30.00fps)
# [10/50] anomaly/Abuse/Abuse010_x264.mp4
#   18 windows (video 30.00fps)
# ...
